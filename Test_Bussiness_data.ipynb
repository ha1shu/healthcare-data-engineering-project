# %%
# %sql
select * from healthcare.transformations.gold_admission_type_analysis

# %%
# %sql
select * from healthcare.transformations.gold_average_billing_by_hospital limit 5

# %%
# %sql
select * from healthcare.transformations.silver_patients_records limit 5
